# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.cluster import KMeans

# %%
#Load the data

# %%
raw_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/23 Customer Data.csv')

# %%
raw_data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for col in raw_data.columns:
  print(col)
# Out:
# CUST_ID
# BALANCE
# BALANCE_FREQUENCY
# PURCHASES
# ONEOFF_PURCHASES
# INSTALLMENTS_PURCHASES
# CASH_ADVANCE
# PURCHASES_FREQUENCY
# ONEOFF_PURCHASES_FREQUENCY
# PURCHASES_INSTALLMENTS_FREQUENCY
# CASH_ADVANCE_FREQUENCY
# CASH_ADVANCE_TRX
# PURCHASES_TRX
# CREDIT_LIMIT
# PAYMENTS
# MINIMUM_PAYMENTS
# PRC_FULL_PAYMENT
# TENURE

# %%
#Data Shape

# %%
raw_data.shape
# Out:
# (8950, 18)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
raw_data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
#Preprocessing data

# %%
#Fixing N/A vallue

# %%
raw_data.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#plot the null data

# %%
plt.figure(figsize=(10,6))
sns.heatmap(raw_data.isna().transpose(), cmap="bone", cbar_kws={'label' : 'Missing data'})
# Out:
# <Axes: >

# %%
#Filling the missing data with mean of minimum payment

# %%
data = raw_data.copy()

# %%
data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].mean(), inplace=True)
data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].mean(), inplace=True)

# %%
#Check dataset again

# %%
data.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
#Drop unused columns

# %%
data.drop(columns=['CUST_ID'], axis=1, inplace=True)

# %%
data.head(

)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#Exploratory data analysis

# %%
for column in data.columns:
  plt.figure(figsize=(10,5))
  sns.displot(data[column], color='black')
  plt.show()

# %%
#Check correlation heatmap

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), cmap='bone_r', annot=True)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Clustering with K-Means

# %%
#Import tools

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
#Standardize the data

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(data)

# %%
#Principal component analysis (PCA)
#Transform dataset into 2 dimensions

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_data)
pca_data = pd.DataFrame(data=principal_components, columns=['PCA 1', 'PCA 2'])
pca_data.shape
# Out:
# (8950, 2)

# %%
pca_data
# Out:
#          PCA 1     PCA 2
# 0    -1.682208 -1.076463
# 1    -1.138234  2.506428
# 2     0.969726 -0.383555
# 3    -0.873678  0.043202
# 4    -1.599406 -0.688605
# ...        ...       ...
# 8945 -0.359637 -2.016142
# 8946 -0.564377 -1.639120
# 8947 -0.926207 -1.810786
# 8948 -2.336535 -0.657979
# 8949 -0.556389 -0.400486
#
# [8950 rows x 2 columns]

# %%
#Finding K values with elbow method

# %%
from yellowbrick.cluster import KElbowVisualizer
km = KMeans(random_state=42)
visualizer = KElbowVisualizer(km, k=(2,10))
visualizer.fit(scaled_data)
visualizer.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
#From the graph the proper value for cluster is 4

# %%
#CLustering with KMeans

# %%
kmeans = KMeans(n_clusters = 4)
label = kmeans.fit_predict(scaled_data)
print(label)

pca_data_kmeans = pd.concat([pca_data, pd.DataFrame({'cluster' : kmeans.labels_})], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 2 3 ... 3 1 1]

# %%
#Plot the cluster map

# %%
plt.figure(figsize=(8,8))
ax = sns.scatterplot(x="PCA 1", y="PCA 2", hue="cluster", data=pca_data_kmeans, palette='deep')
plt.title('Clustering with K-Means method')
plt.show()

# %%
#Finding the cluster centers

# %%
cluster_center = pd.DataFrame(data=kmeans.cluster_centers_, columns=[data.columns])

# %%
cluster_center = scaler.inverse_transform(cluster_center)
cluster_center = pd.DataFrame(data=cluster_center, columns=[data.columns])
cluster_center
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0  3551.153761          0.986879  7681.620098      5095.878826
# 1  1011.905311          0.789818   270.041384       209.906657
# 2  4598.958127          0.968442   501.477623       320.106480
# 3   894.907458          0.934734  1236.178934       593.974874
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            2587.208264   653.638891            0.946418
# 1              60.401816   595.702182            0.170189
# 2             181.455938  4517.640268            0.287491
# 3             642.478274   210.570626            0.885165
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.739031                         0.788060
# 1                   0.086303                         0.080598
# 2                   0.138818                         0.185361
# 3                   0.297070                         0.711842
#
# ...

# %%
#Labelling the original data

# %%
labelled_data = pd.concat([data, pd.DataFrame({'Cluster' : kmeans.labels_})], axis=1)
labelled_data
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
#Visualizing labelled data

# %%
sns.countplot(x='Cluster', data=labelled_data, palette='deep')
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %%
#plot every feature in dataset with their clusters

# %%
for c in labelled_data.drop(['Cluster'], axis=1):
  grid = sns.FacetGrid(labelled_data, col='Cluster', hue='Cluster', palette='deep')
  grid = grid.map(plt.hist, c)
plt.show()
