# %%
# Machine Learning
# Build model

# %%
import pandas as pd
import numpy as np

# %%
#load the data

# %%
data_preprocessed = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Deep Learning/df_preprocessed_absenteisme.csv')

# %%
data_preprocessed.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  Day of the week  \
# 0         0         0         0         1            7                1
# 1         0         0         0         0            7                1
# 2         0         0         0         1            7                2
# 3         1         0         0         0            7                3
# 4         0         0         0         1            7                3
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# 3                     279                 5   39                  239.554
# 4                     289                36   33                  239.554
#
#    Body Mass Index  Education  Children  Pets  Absenteeism Time in Hours
# ...

# %%
#Create the targets for logistic regression

# %%
data_preprocessed['Absenteeism Time in Hours'].median()
# Out:
# 3.0

# %%
targets = np.where(data_preprocessed['Absenteeism Time in Hours'] > data_preprocessed['Absenteeism Time in Hours'].median(), 1, 0)

# %%
data_preprocessed['Excessive Absenteeism'] = targets
data_preprocessed.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  Day of the week  \
# 0         0         0         0         1            7                1
# 1         0         0         0         0            7                1
# 2         0         0         0         1            7                2
# 3         1         0         0         0            7                3
# 4         0         0         0         1            7                3
#
#    Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                     289                36   33                  239.554
# 1                     118                13   50                  239.554
# 2                     179                51   38                  239.554
# 3                     279                 5   39                  239.554
# 4                     289                36   33                  239.554
#
#    Body Mass Index  Education  Children  Pets  Absenteeism Time in Hours  \
# ...

# %%
#Balancing dataset

# %%
targets.sum() /   targets.shape[0]
# Out:
# 0.45571428571428574

# %%
data_with_targets = data_preprocessed.drop(['Absenteeism Time in Hours'], axis=1)

# %%
#Select the inputs for regression

# %%
data_with_targets.iloc[:,:14]
# Out:
#      Reason_1  Reason_2  Reason_3  Reason_4  Month Value  Day of the week  \
# 0           0         0         0         1            7                1
# 1           0         0         0         0            7                1
# 2           0         0         0         1            7                2
# 3           1         0         0         0            7                3
# 4           0         0         0         1            7                3
# ..        ...       ...       ...       ...          ...              ...
# 695         1         0         0         0            5                2
# 696         1         0         0         0            5                2
# 697         1         0         0         0            5                3
# 698         0         0         0         1            5                3
# 699         0         0         0         1            5                3
#
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# ...

# %%
unscaled_inputs = data_with_targets.iloc[:,:14]

# %%
#Standardize the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
absenteeism_scaler = StandardScaler()

# %%
absenteeism_scaler.fit(unscaled_inputs)
# Out:
# StandardScaler()

# %%
scaled_inputs = absenteeism_scaler.transform(unscaled_inputs)

# %%
# Out:
# array([[-0.57735027, -0.09298136, -0.29773641, ..., -0.44798003,
#          0.88046927,  0.26848661],
#        [-0.57735027, -0.09298136, -0.29773641, ..., -0.44798003,
#         -0.01928035, -0.58968976],
#        [-0.57735027, -0.09298136, -0.29773641, ..., -0.44798003,
#         -0.91902997, -0.58968976],
#        ...,
#        [ 1.73205081, -0.09298136, -0.29773641, ...,  2.23224237,
#         -0.91902997, -0.58968976],
#        [-0.57735027, -0.09298136, -0.29773641, ...,  2.23224237,
#         -0.91902997, -0.58968976],
#        [-0.57735027, -0.09298136, -0.29773641, ..., -0.44798003,
#         -0.01928035,  0.26848661]])

# %%
scaled_inputs.shape
# Out:
# (700, 14)

# %%
#split dataset into train & test sample

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(scaled_inputs, targets, train_size=0.8, random_state=20)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (560, 14) (140, 14) (560,) (140,)
