# %%
import numpy as np
import tensorflow as tf

# %%
#Load the data

# %%
npz = np.load('/content/drive/MyDrive/Colab Notebooks/Deep Learning/Audiobooks_data_train.npz')

train_inputs = npz['inputs'].astype(np.float)
train_targets = npz['targets'].astype(np.int)

npz = np.load('/content/drive/MyDrive/Colab Notebooks/Deep Learning/Audiobooks_data_validation.npz')

validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)
# Out:
# <ipython-input-3-2f280aba128c>:3: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_inputs = npz['inputs'].astype(np.float)
# <ipython-input-3-2f280aba128c>:4: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_targets = npz['targets'].astype(np.int)
# <ipython-input-3-2f280aba128c>:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)
# <ipython-input-3-2f280aba128c>:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   validation_inputs, validation_targets = npz['inputs'].astype(np.float), npz['targets'].astype(np.int)

# %%
# Model
# --> Outline, optimizers, loss, early stopping and training

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

#Model
model = tf.keras.Sequential([
                            tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                            tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                            tf.keras.layers.Dense(output_size, activation='softmax')
                            ])

#loss function
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100

max_epochs = 100

model.fit(train_inputs,
          train_targets,
          batch_size = batch_size,
          epochs = max_epochs,
          validation_data=(validation_inputs, validation_targets),
          verbose = 2)
# Out:
# Epoch 1/100
# 36/36 - 1s - loss: 0.6007 - accuracy: 0.6910 - val_loss: 0.5144 - val_accuracy: 0.7427 - 1s/epoch - 36ms/step
# Epoch 2/100
# 36/36 - 0s - loss: 0.4689 - accuracy: 0.7538 - val_loss: 0.4248 - val_accuracy: 0.7763 - 112ms/epoch - 3ms/step
# Epoch 3/100
# 36/36 - 0s - loss: 0.4119 - accuracy: 0.7784 - val_loss: 0.3874 - val_accuracy: 0.8054 - 115ms/epoch - 3ms/step
# Epoch 4/100
# 36/36 - 0s - loss: 0.3845 - accuracy: 0.7857 - val_loss: 0.3714 - val_accuracy: 0.7696 - 131ms/epoch - 4ms/step
# Epoch 5/100
# 36/36 - 0s - loss: 0.3716 - accuracy: 0.7924 - val_loss: 0.3581 - val_accuracy: 0.8098 - 169ms/epoch - 5ms/step
# Epoch 6/100
# 36/36 - 0s - loss: 0.3601 - accuracy: 0.8078 - val_loss: 0.3478 - val_accuracy: 0.8367 - 161ms/epoch - 4ms/step
# Epoch 7/100
# 36/36 - 0s - loss: 0.3513 - accuracy: 0.8114 - val_loss: 0.3433 - val_accuracy: 0.8210 - 163ms/epoch - 5ms/step
# Epoch 8/100
# 36/36 - 0s - loss: 0.3472 - accuracy: 0.8078 - val_loss: 0.3385 - val_accuracy: 0.8322 - 174ms/epoch - 5ms/step
# Epoch 9/100
# 36/36 - 0s - loss: 0.3409 - accuracy: 0.8122 - val_loss: 0.3367 - val_accuracy: 0.8456 - 225ms/epoch - 6ms/step
# Epoch 10/100
# 36/36 - 0s - loss: 0.3384 - accuracy: 0.8178 - val_loss: 0.3403 - val_accuracy: 0.8389 - 370ms/epoch - 10ms/step
# Epoch 11/100
# 36/36 - 0s - loss: 0.3373 - accuracy: 0.8156 - val_loss: 0.3363 - val_accuracy: 0.8345 - 300ms/epoch - 8ms/step
# Epoch 12/100
# 36/36 - 0s - loss: 0.3350 - accuracy: 0.8184 - val_loss: 0.3288 - val_accuracy: 0.8054 - 176ms/epoch - 5ms/step
# Epoch 13/100
# 36/36 - 0s - loss: 0.3320 - accuracy: 0.8170 - val_loss: 0.3430 - val_accuracy: 0.7897 - 245ms/epoch - 7ms/step
# Epoch 14/100
# 36/36 - 0s - loss: 0.3312 - accuracy: 0.8142 - val_loss: 0.3238 - val_accuracy: 0.8434 - 155ms/epoch - 4ms/step
# Epoch 15/100
# 36/36 - 0s - loss: 0.3251 - accuracy: 0.8237 - val_loss: 0.3262 - val_accuracy: 0.8322 - 150ms/epoch - 4ms/step
# Epoch 16/100
# 36/36 - 0s - loss: 0.3259 - accuracy: 0.8206 - val_loss: 0.3258 - val_accuracy: 0.8277 - 156ms/epoch - 4ms/step
# Epoch 17/100
# 36/36 - 0s - loss: 0.3252 - accuracy: 0.8184 - val_loss: 0.3258 - val_accuracy: 0.8277 - 145ms/epoch - 4ms/step
# Epoch 18/100
# 36/36 - 0s - loss: 0.3262 - accuracy: 0.8251 - val_loss: 0.3301 - val_accuracy: 0.8076 - 158ms/epoch - 4ms/step
# Epoch 19/100
# 36/36 - 0s - loss: 0.3252 - accuracy: 0.8215 - val_loss: 0.3269 - val_accuracy: 0.8367 - 179ms/epoch - 5ms/step
# Epoch 20/100
# 36/36 - 0s - loss: 0.3192 - accuracy: 0.8215 - val_loss: 0.3296 - val_accuracy: 0.8345 - 180ms/epoch - 5ms/step
# Epoch 21/100
# 36/36 - 0s - loss: 0.3182 - accuracy: 0.8248 - val_loss: 0.3306 - val_accuracy: 0.8412 - 157ms/epoch - 4ms/step
# Epoch 22/100
# 36/36 - 0s - loss: 0.3231 - accuracy: 0.8156 - val_loss: 0.3380 - val_accuracy: 0.8300 - 171ms/epoch - 5ms/step
# Epoch 23/100
# 36/36 - 0s - loss: 0.3191 - accuracy: 0.8273 - val_loss: 0.3302 - val_accuracy: 0.8367 - 161ms/epoch - 4ms/step
# Epoch 24/100
# 36/36 - 0s - loss: 0.3166 - accuracy: 0.8268 - val_loss: 0.3236 - val_accuracy: 0.8367 - 164ms/epoch - 5ms/step
# Epoch 25/100
# 36/36 - 0s - loss: 0.3150 - accuracy: 0.8287 - val_loss: 0.3239 - val_accuracy: 0.8367 - 212ms/epoch - 6ms/step
# Epoch 26/100
# 36/36 - 0s - loss: 0.3155 - accuracy: 0.8332 - val_loss: 0.3217 - val_accuracy: 0.8143 - 150ms/epoch - 4ms/step
# Epoch 27/100
# 36/36 - 0s - loss: 0.3154 - accuracy: 0.8240 - val_loss: 0.3283 - val_accuracy: 0.8300 - 158ms/epoch - 4ms/step
# Epoch 28/100
# 36/36 - 0s - loss: 0.3159 - accuracy: 0.8279 - val_loss: 0.3204 - val_accuracy: 0.8300 - 159ms/epoch - 4ms/step
# Epoch 29/100
# 36/36 - 0s - loss: 0.3166 - accuracy: 0.8231 - val_loss: 0.3335 - val_accuracy: 0.8345 - 156ms/epoch - 4ms/step
# Epoch 30/100
# 36/36 - 0s - loss: 0.3118 - accuracy: 0.8332 - val_loss: 0.3252 - val_accuracy: 0.8277 - 181ms/epoch - 5ms/step
# Epoch 31/100
# 36/36 - 0s - loss: 0.3160 - accuracy: 0.8273 - val_loss: 0.3451 - val_accuracy: 0.8031 - 212ms/epoch - 6ms/step
# Epoch 32/100
# 36/36 - 0s - loss: 0.3168 - accuracy: 0.8293 - val_loss: 0.3252 - val_accuracy: 0.8233 - 189ms/epoch - 5ms/step
# Epoch 33/100
# 36/36 - 0s - loss: 0.3134 - accuracy: 0.8310 - val_loss: 0.3227 - val_accuracy: 0.8300 - 175ms/epoch - 5ms/step
# Epoch 34/100
# 36/36 - 0s - loss: 0.3104 - accuracy: 0.8363 - val_loss: 0.3388 - val_accuracy: 0.8345 - 182ms/epoch - 5ms/step
# Epoch 35/100
# 36/36 - 0s - loss: 0.3184 - accuracy: 0.8201 - val_loss: 0.3275 - val_accuracy: 0.8389 - 183ms/epoch - 5ms/step
# Epoch 36/100
# 36/36 - 0s - loss: 0.3091 - accuracy: 0.8301 - val_loss: 0.3226 - val_accuracy: 0.8076 - 205ms/epoch - 6ms/step
# Epoch 37/100
# 36/36 - 0s - loss: 0.3170 - accuracy: 0.8217 - val_loss: 0.3323 - val_accuracy: 0.8121 - 173ms/epoch - 5ms/step
# Epoch 38/100
# 36/36 - 0s - loss: 0.3128 - accuracy: 0.8270 - val_loss: 0.3181 - val_accuracy: 0.8300 - 178ms/epoch - 5ms/step
# Epoch 39/100
# 36/36 - 0s - loss: 0.3101 - accuracy: 0.8326 - val_loss: 0.3242 - val_accuracy: 0.8188 - 181ms/epoch - 5ms/step
# Epoch 40/100
# 36/36 - 0s - loss: 0.3097 - accuracy: 0.8290 - val_loss: 0.3314 - val_accuracy: 0.8322 - 167ms/epoch - 5ms/step
# Epoch 41/100
# 36/36 - 0s - loss: 0.3094 - accuracy: 0.8340 - val_loss: 0.3298 - val_accuracy: 0.8255 - 120ms/epoch - 3ms/step
# Epoch 42/100
# 36/36 - 0s - loss: 0.3103 - accuracy: 0.8343 - val_loss: 0.3212 - val_accuracy: 0.8054 - 138ms/epoch - 4ms/step
# Epoch 43/100
# 36/36 - 0s - loss: 0.3081 - accuracy: 0.8349 - val_loss: 0.3252 - val_accuracy: 0.8277 - 127ms/epoch - 4ms/step
# Epoch 44/100
# 36/36 - 0s - loss: 0.3078 - accuracy: 0.8310 - val_loss: 0.3339 - val_accuracy: 0.8210 - 111ms/epoch - 3ms/step
# Epoch 45/100
# 36/36 - 0s - loss: 0.3125 - accuracy: 0.8301 - val_loss: 0.3202 - val_accuracy: 0.8277 - 125ms/epoch - 3ms/step
# Epoch 46/100
# 36/36 - 0s - loss: 0.3070 - accuracy: 0.8368 - val_loss: 0.3206 - val_accuracy: 0.8300 - 127ms/epoch - 4ms/step
# Epoch 47/100
# 36/36 - 0s - loss: 0.3050 - accuracy: 0.8318 - val_loss: 0.3237 - val_accuracy: 0.8434 - 120ms/epoch - 3ms/step
# Epoch 48/100
# 36/36 - 0s - loss: 0.3067 - accuracy: 0.8335 - val_loss: 0.3216 - val_accuracy: 0.8188 - 124ms/epoch - 3ms/step
# Epoch 49/100
# 36/36 - 0s - loss: 0.3095 - accuracy: 0.8254 - val_loss: 0.3243 - val_accuracy: 0.8188 - 127ms/epoch - 4ms/step
# Epoch 50/100
# 36/36 - 0s - loss: 0.3090 - accuracy: 0.8265 - val_loss: 0.3169 - val_accuracy: 0.8277 - 112ms/epoch - 3ms/step
# Epoch 51/100
# 36/36 - 0s - loss: 0.3095 - accuracy: 0.8315 - val_loss: 0.3203 - val_accuracy: 0.8233 - 114ms/epoch - 3ms/step
# Epoch 52/100
# 36/36 - 0s - loss: 0.3095 - accuracy: 0.8290 - val_loss: 0.3248 - val_accuracy: 0.8277 - 128ms/epoch - 4ms/step
# Epoch 53/100
# 36/36 - 0s - loss: 0.3058 - accuracy: 0.8357 - val_loss: 0.3158 - val_accuracy: 0.8255 - 119ms/epoch - 3ms/step
# Epoch 54/100
# 36/36 - 0s - loss: 0.3078 - accuracy: 0.8293 - val_loss: 0.3266 - val_accuracy: 0.7875 - 140ms/epoch - 4ms/step
# Epoch 55/100
# 36/36 - 0s - loss: 0.3121 - accuracy: 0.8284 - val_loss: 0.3147 - val_accuracy: 0.8277 - 138ms/epoch - 4ms/step
# Epoch 56/100
# 36/36 - 0s - loss: 0.3058 - accuracy: 0.8282 - val_loss: 0.3223 - val_accuracy: 0.8210 - 128ms/epoch - 4ms/step
# Epoch 57/100
# 36/36 - 0s - loss: 0.3043 - accuracy: 0.8340 - val_loss: 0.3227 - val_accuracy: 0.8434 - 108ms/epoch - 3ms/step
# Epoch 58/100
# 36/36 - 0s - loss: 0.3054 - accuracy: 0.8301 - val_loss: 0.3199 - val_accuracy: 0.8277 - 107ms/epoch - 3ms/step
# Epoch 59/100
# 36/36 - 0s - loss: 0.3029 - accuracy: 0.8382 - val_loss: 0.3194 - val_accuracy: 0.8412 - 125ms/epoch - 3ms/step
# Epoch 60/100
# 36/36 - 0s - loss: 0.3066 - accuracy: 0.8307 - val_loss: 0.3246 - val_accuracy: 0.8345 - 119ms/epoch - 3ms/step
# Epoch 61/100
# 36/36 - 0s - loss: 0.3026 - accuracy: 0.8382 - val_loss: 0.3223 - val_accuracy: 0.8188 - 117ms/epoch - 3ms/step
# Epoch 62/100
# 36/36 - 0s - loss: 0.3042 - accuracy: 0.8365 - val_loss: 0.3224 - val_accuracy: 0.8389 - 117ms/epoch - 3ms/step
# Epoch 63/100
# 36/36 - 0s - loss: 0.3036 - accuracy: 0.8379 - val_loss: 0.3189 - val_accuracy: 0.8300 - 121ms/epoch - 3ms/step
# Epoch 64/100
# 36/36 - 0s - loss: 0.3052 - accuracy: 0.8343 - val_loss: 0.3377 - val_accuracy: 0.8054 - 119ms/epoch - 3ms/step
# Epoch 65/100
# 36/36 - 0s - loss: 0.3032 - accuracy: 0.8377 - val_loss: 0.3206 - val_accuracy: 0.8121 - 128ms/epoch - 4ms/step
# Epoch 66/100
# 36/36 - 0s - loss: 0.3027 - accuracy: 0.8307 - val_loss: 0.3423 - val_accuracy: 0.7987 - 134ms/epoch - 4ms/step
# Epoch 67/100
# 36/36 - 0s - loss: 0.3028 - accuracy: 0.8335 - val_loss: 0.3297 - val_accuracy: 0.8031 - 139ms/epoch - 4ms/step
# Epoch 68/100
# 36/36 - 0s - loss: 0.3059 - accuracy: 0.8326 - val_loss: 0.3189 - val_accuracy: 0.8367 - 113ms/epoch - 3ms/step
# Epoch 69/100
# 36/36 - 0s - loss: 0.3049 - accuracy: 0.8346 - val_loss: 0.3125 - val_accuracy: 0.8255 - 111ms/epoch - 3ms/step
# Epoch 70/100
# 36/36 - 0s - loss: 0.3020 - accuracy: 0.8354 - val_loss: 0.3163 - val_accuracy: 0.8277 - 124ms/epoch - 3ms/step
# Epoch 71/100
# 36/36 - 0s - loss: 0.3060 - accuracy: 0.8318 - val_loss: 0.3224 - val_accuracy: 0.8210 - 121ms/epoch - 3ms/step
# Epoch 72/100
# 36/36 - 0s - loss: 0.3039 - accuracy: 0.8304 - val_loss: 0.3238 - val_accuracy: 0.8098 - 114ms/epoch - 3ms/step
# Epoch 73/100
# 36/36 - 0s - loss: 0.3042 - accuracy: 0.8388 - val_loss: 0.3301 - val_accuracy: 0.8367 - 115ms/epoch - 3ms/step
# Epoch 74/100
# 36/36 - 0s - loss: 0.3031 - accuracy: 0.8338 - val_loss: 0.3173 - val_accuracy: 0.8188 - 115ms/epoch - 3ms/step
# Epoch 75/100
# 36/36 - 0s - loss: 0.2994 - accuracy: 0.8379 - val_loss: 0.3109 - val_accuracy: 0.8322 - 117ms/epoch - 3ms/step
# Epoch 76/100
# 36/36 - 0s - loss: 0.3035 - accuracy: 0.8304 - val_loss: 0.3196 - val_accuracy: 0.8277 - 100ms/epoch - 3ms/step
# Epoch 77/100
# 36/36 - 0s - loss: 0.3082 - accuracy: 0.8298 - val_loss: 0.3169 - val_accuracy: 0.8322 - 125ms/epoch - 3ms/step
# Epoch 78/100
# 36/36 - 0s - loss: 0.3055 - accuracy: 0.8360 - val_loss: 0.3117 - val_accuracy: 0.8367 - 124ms/epoch - 3ms/step
# Epoch 79/100
# 36/36 - 0s - loss: 0.3001 - accuracy: 0.8343 - val_loss: 0.3126 - val_accuracy: 0.8345 - 124ms/epoch - 3ms/step
# Epoch 80/100
# 36/36 - 0s - loss: 0.3069 - accuracy: 0.8326 - val_loss: 0.3125 - val_accuracy: 0.8210 - 114ms/epoch - 3ms/step
# Epoch 81/100
# 36/36 - 0s - loss: 0.3039 - accuracy: 0.8307 - val_loss: 0.3172 - val_accuracy: 0.8300 - 133ms/epoch - 4ms/step
# Epoch 82/100
# 36/36 - 0s - loss: 0.3043 - accuracy: 0.8335 - val_loss: 0.3362 - val_accuracy: 0.8367 - 111ms/epoch - 3ms/step
# Epoch 83/100
# 36/36 - 0s - loss: 0.2984 - accuracy: 0.8338 - val_loss: 0.3210 - val_accuracy: 0.8233 - 105ms/epoch - 3ms/step
# Epoch 84/100
# 36/36 - 0s - loss: 0.3018 - accuracy: 0.8351 - val_loss: 0.3216 - val_accuracy: 0.8300 - 115ms/epoch - 3ms/step
# Epoch 85/100
# 36/36 - 0s - loss: 0.3033 - accuracy: 0.8351 - val_loss: 0.3245 - val_accuracy: 0.8389 - 112ms/epoch - 3ms/step
# Epoch 86/100
# 36/36 - 0s - loss: 0.2999 - accuracy: 0.8371 - val_loss: 0.3205 - val_accuracy: 0.8210 - 115ms/epoch - 3ms/step
# Epoch 87/100
# 36/36 - 0s - loss: 0.3016 - accuracy: 0.8346 - val_loss: 0.3145 - val_accuracy: 0.8322 - 115ms/epoch - 3ms/step
# Epoch 88/100
# 36/36 - 0s - loss: 0.3006 - accuracy: 0.8312 - val_loss: 0.3216 - val_accuracy: 0.8210 - 120ms/epoch - 3ms/step
# Epoch 89/100
# 36/36 - 0s - loss: 0.3064 - accuracy: 0.8290 - val_loss: 0.3204 - val_accuracy: 0.8233 - 110ms/epoch - 3ms/step
# Epoch 90/100
# 36/36 - 0s - loss: 0.3025 - accuracy: 0.8374 - val_loss: 0.3124 - val_accuracy: 0.8300 - 128ms/epoch - 4ms/step
# Epoch 91/100
# 36/36 - 0s - loss: 0.3026 - accuracy: 0.8360 - val_loss: 0.3235 - val_accuracy: 0.8188 - 120ms/epoch - 3ms/step
# Epoch 92/100
# 36/36 - 0s - loss: 0.3011 - accuracy: 0.8326 - val_loss: 0.3195 - val_accuracy: 0.8121 - 110ms/epoch - 3ms/step
# Epoch 93/100
# 36/36 - 0s - loss: 0.3025 - accuracy: 0.8413 - val_loss: 0.3197 - val_accuracy: 0.8210 - 99ms/epoch - 3ms/step
# Epoch 94/100
# 36/36 - 0s - loss: 0.3002 - accuracy: 0.8351 - val_loss: 0.3238 - val_accuracy: 0.8412 - 121ms/epoch - 3ms/step
# Epoch 95/100
# 36/36 - 0s - loss: 0.3017 - accuracy: 0.8329 - val_loss: 0.3196 - val_accuracy: 0.8255 - 103ms/epoch - 3ms/step
# Epoch 96/100
# 36/36 - 0s - loss: 0.3037 - accuracy: 0.8321 - val_loss: 0.3159 - val_accuracy: 0.8345 - 127ms/epoch - 4ms/step
# Epoch 97/100
# 36/36 - 0s - loss: 0.3003 - accuracy: 0.8349 - val_loss: 0.3217 - val_accuracy: 0.8166 - 117ms/epoch - 3ms/step
# Epoch 98/100
# 36/36 - 0s - loss: 0.2983 - accuracy: 0.8371 - val_loss: 0.3195 - val_accuracy: 0.8210 - 107ms/epoch - 3ms/step
# Epoch 99/100
# 36/36 - 0s - loss: 0.2993 - accuracy: 0.8357 - val_loss: 0.3168 - val_accuracy: 0.8121 - 112ms/epoch - 3ms/step
# Epoch 100/100
# 36/36 - 0s - loss: 0.3031 - accuracy: 0.8335 - val_loss: 0.3218 - val_accuracy: 0.8456 - 114ms/epoch - 3ms/step
